# %%
import numpy as np
import yaml
import load_data
import simSatellite
import ugali.utils.projector

# %%
with open('../local_v2.yaml') as ymlfile:
    cfg = yaml.load(ymlfile)
inputs = load_data.Inputs(cfg)
# Out:
# /Users/mcnanna/anaconda2/envs/ugali-env/lib/python2.7/site-packages/ipykernel_launcher.py:2: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# NSIDE = 4096
# ORDERING = RING in fits file
# INDXSCHM = EXPLICIT
# NSIDE = 4096
# ORDERING = RING in fits file
# INDXSCHM = EXPLICIT
# NSIDE = 4096
# ORDERING = RING in fits file
# INDXSCHM = EXPLICIT
# NSIDE = 4096
# ORDERING = NESTED in fits file
# INDXSCHM = IMPLICIT
# Ordering converted to RING

# %%
log_r_physical_pcs = np.arange(1.4, 3.8, 0.2)
r_physicals = 10**log_r_physical_pcs
abs_mags = np.arange(-2.5, -14.5, -0.5)

ra, dec = 2.87, -38.44
distance = 2000 #kpc

# %%
tucB = simSatellite.SimSatellite(inputs, ra, dec, 1400, -6.9, 80, use_completeness=False, use_efficiency=False)
stars = tucB.stars
cut = stars['PSF_MAG_R_CORRECTED'] < 27.0
stars = stars[cut]
angseps = ugali.utils.projector.angsep(ra, dec, stars['RA'], stars['DEC'])

radius = 0.5 * tucB.a_h
area = np.pi*(radius*3600)**2
n = np.count_nonzero(angseps < radius)
density = n/area
print(round(area,1), n, round(density,3))
# Out:
# (109.1, 181, 1.659)

# %%
# Quick and dirty version. Uses r_mag = 27.0 as cutoff for inclusion of stars. 
# Looks at 0.5*r_h density to determine if we can skip this magnitude for being too dim
# Looks at 1*r_h to determine if we can safely say its blended at all brighter mags

n_trials = 3

n_r = len(r_physicals)
n_m = len(abs_mags)

radii_factors = 1/2., 1., 2.

densities = np.zeros((n_r, n_m, len(radii_factors)))

for i in range(n_r):
    blended_flag = False # Reset flag
    for j in range(n_m):
        if blended_flag: 
            # If it was blended at dimmer mags, assume blended when brighter
            densities[i,j] = [99.9, 99.9, 99.9]
            continue
        if i > 0 and densities[i-1, j, 0] < 1.0: ##### Choosing only 0.5*r_h density here #####
            # If it wasn't blended at this mag at a smaller radius, it won't be here either
            densities[i, j] = [0., 0., 0.]
            continue
            
        r, m = r_physicals[i], abs_mags[j]
        if m < -12.6:
            continue # It takes too much memory to simulate brighter galaxies
        for _ in range(n_trials):
            sim = simSatellite.SimSatellite(inputs, ra, dec, distance, m, r, use_completeness=False, use_efficiency=False)
            stars = sim.stars
            cut = stars['PSF_MAG_R_CORRECTED'] < 27.0
            stars = stars[cut]
            
            angseps = ugali.utils.projector.angsep(ra, dec, stars['RA'], stars['DEC'])
            for k, factor in enumerate(radii_factors):
                radius = factor*sim.a_h # degrees
                n = np.count_nonzero(angseps < radius)
                area = np.pi * (radius*3600.)**2 # Assuming simple area calculation A = pi*r^2
                density = n/area
                #densities[i, j, k] += density
                densities[i, j, k] = max(densities[i, j, k], density)
        #densities[i, j] /= n_trials
            
        if densities[i,j][1] > 1.0: ##### Choosing only 1*r_h density here #####
            blended_flag = True
            
        print("({}, {}): {}, {}, {}".format(r, m, *densities[i,j]))
# Out:
# (25.1188643151, -2.5): 0.379445877907, 0.237153673692, 0.0711461021076
# (25.1188643151, -3.0): 0.379445877907, 0.237153673692, 0.0711461021076
# (25.1188643151, -3.5): 0.379445877907, 0.28458440843, 0.142292204215
# (25.1188643151, -4.0): 1.32806057268, 0.616599551599, 0.260869041061
# (25.1188643151, -4.5): 2.27667526744, 1.18576836846, 0.450591980015
# (39.8107170553, -4.0): 0.528710436869, 0.321002765242, 0.136898238118
# (39.8107170553, -4.5): 0.830830686509, 0.37765031205, 0.141618867019
# (39.8107170553, -5.0): 1.05742087374, 0.604240499279, 0.278517105137
# (39.8107170553, -5.5): 1.43507118579, 0.944125780124, 0.415415343255
# (39.8107170553, -6.0): 1.96378162266, 1.43507118579, 0.585357983677
# (63.095734448, -5.0): 0.390897772613, 0.233035210596, 0.0958451269387
# (63.095734448, -5.5): 0.631450248066, 0.39841503747, 0.140948716086
# (63.095734448, -6.0): 1.02234802068, 0.661519307498, 0.276259483529
# (63.095734448, -6.5): 1.38317673386, 1.01483075582, 0.411570250972
# (100.0, -6.0): 0.43094549396, 0.242406840353, 0.0995065116263
# (100.0, -6.5): 0.550652575616, 0.32320912047, 0.130929620561
# (100.0, -7.0): 1.02948090224, 0.637440209817, 0.253629379258
# (100.0, -7.5): 1.54422135336, 0.94568594508, 0.399522385026
# (100.0, -8.0): 2.66946792092, 1.47838245845, 0.590305546415
# (158.489319246, -7.0): 0.352656231597, 0.228749988063, 0.0941210888384
# (158.489319246, -7.5): 0.595703093914, 0.377675761541, 0.140883781711
# (158.489319246, -8.0): 0.972187449268, 0.593320281538, 0.234111315908
# (158.489319246, -8.5): 1.47257804816, 0.938828076008, 0.370229472868
# (158.489319246, -9.0): 2.12546863909, 1.35820305412, 0.549536104136
# (251.188643151, -8.5): 0.610907860251, 0.375651417173, 0.147391007432
# (251.188643151, -9.0): 0.977073130525, 0.572014657968, 0.225414565671
# (251.188643151, -9.5): 1.50260566869, 0.901658262684, 0.354426163488
# (251.188643151, -10.0): 2.20647776854, 1.40537266298, 0.558852629146
# (398.107170553, -9.5): 0.549858847155, 0.346494156775, 0.138172806114
# (398.107170553, -10.0): 0.876904013113, 0.544571742855, 0.219273209567
# (398.107170553, -10.5): 1.45848548607, 0.903339534611, 0.358626172891
# (398.107170553, -11.0): 2.16015975668, 1.39145255655, 0.553965794244
# (630.95734448, -10.5): 0.571011419854, 0.352183847027, 0.140704400357
# (630.95734448, -11.0): 0.894554488713, 0.559134141769, 0.220612923172
# (630.95734448, -11.5): 1.41595196214, 0.875084773371, 0.351262982112
# (630.95734448, -12.0): 2.22691446837, 1.38114702699, 0.552180672004
# (1000.0, -11.5): 0.561545873719, 0.348706700095, 0.138979910336
# (1000.0, -12.0): 0.888705300894, 0.549994141293, 0.219355727345
# (1000.0, -12.5): 1.40655809341, 0.865811323416, 0.346522046035
# (1584.89319246, -12.5): 0.564059228675, 0.347771394158, 0.138626038257

# %%
# Full calculation (abs_mag > -13.0)

n_trials = 3

n_r = len(r_physicals)
n_m = len(abs_mags)

radii_factors = 1/2., 1., 2.

densities = np.zeros((n_r, n_m, len(radii_factors)))

for i in range(n_r):
    for j in range(n_m):
        r, m = r_physicals[i], abs_mags[j]
        if m < -13.1:
            continue # It takes too much memory to simulate brighter galaxies
        for _ in range(n_trials):
            sim = simSatellite.SimSatellite(inputs, ra, dec, distance, m, r, use_completeness=False, use_efficiency=True)
            stars = sim.stars
            angseps = ugali.utils.projector.angsep(ra, dec, stars['RA'], stars['DEC'])
        
            for k, factor in enumerate(radii_factors):
                radius = factor*sim.a_h # degrees
                n = np.count_nonzero(angseps < radius)
                area = np.pi * (radius*3600.)**2 # Assuming simple area calculation A = pi*r^2
                density = n/area
                densities[i, j, k] += density
        densities[i, j] /= n_trials
            
        print("({}, {}): {}, {}, {}".format(r, m, *densities[i,j]))
# Out:
# (25.1188643151, -2.5): 0.0, 0.0158102449128, 0.0079051224564
# (25.1188643151, -3.0): 0.0, 0.0316204898256, 0.0118576836846
# (25.1188643151, -3.5): 0.0, 0.0632409796512, 0.0237153673692
# (25.1188643151, -4.0): 0.126481959302, 0.142292204215, 0.0474307347384
# (25.1188643151, -4.5): 0.50592783721, 0.205533183866, 0.0711461021076
# (25.1188643151, -5.0): 0.632409796512, 0.379445877907, 0.134387081759
# (25.1188643151, -5.5): 0.758891755814, 0.39525612282, 0.158102449128
# (25.1188643151, -6.0): 1.32806057268, 0.711461021076, 0.233201112464
# (25.1188643151, -6.5): 1.58102449128, 0.837942980378, 0.363635632994
# (25.1188643151, -7.0): 1.96047036919, 1.32806057268, 0.608694429143
# (39.8107170553, -2.5): 0.0, 0.012588343735, 0.00472062890062
# (39.8107170553, -3.0): 0.0, 0.012588343735, 0.00472062890062
# (39.8107170553, -3.5): 0.0503533749399, 0.02517668747, 0.00786771483437
# (39.8107170553, -4.0): 0.0503533749399, 0.02517668747, 0.0220296015362
# (39.8107170553, -4.5): 0.22659018723, 0.0881184061449, 0.0283237734037
# (39.8107170553, -5.0): 0.12588343735, 0.0881184061449, 0.0330444023043
# (39.8107170553, -5.5): 0.27694356217, 0.169942640422, 0.0692358905424
# (39.8107170553, -6.0): 0.2517668747, 0.258061046567, 0.0944125780124
# (39.8107170553, -6.5): 0.453180374459, 0.383944483917, 0.152633667787
# (39.8107170553, -7.0): 0.704947249159, 0.547592952472, 0.228163730197
# (39.8107170553, -7.5): 1.61130799808, 0.975596639461, 0.394959284685
# (39.8107170553, -8.0): 2.92049574652, 1.72460309169, 0.648299702352
# (63.095734448, -2.5): 0.0200460396212, 0.00501150990529, 0.00187931621448
# (63.095734448, -3.0): 0.0100230198106, 0.00501150990529, 0.00125287747632
# (63.095734448, -3.5): 0.0200460396212, 0.00501150990529, 0.00438507116713
# (63.095734448, -4.0): 0.0100230198106, 0.0175402846685, 0.00689082611977
# (63.095734448, -4.5): 0.0300690594317, 0.0200460396212, 0.00939658107242
# (63.095734448, -5.0): 0.070161138674, 0.0451035891476, 0.0187931621448
# (63.095734448, -5.5): 0.0801841584846, 0.0451035891476, 0.0206724783593
# (63.095734448, -6.0): 0.130299257538, 0.077678403532, 0.0332012531225
# (63.095734448, -6.5): 0.230529455643, 0.137816522395, 0.0607645576016
# (63.095734448, -7.0): 0.35080569337, 0.243058230407, 0.0939658107242
# (63.095734448, -7.5): 0.501150990529, 0.35080569337, 0.152224613373
# (63.095734448, -8.0): 0.821887624467, 0.538737314819, 0.238046720501
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-36-1c31bef4517d> in <module>()
#      19             continue # It takes too much memory to simulate brighter galaxies
#      20         for _ in range(n_trials):
# ---> 21             sim = simSatellite.SimSatellite(inputs, ra, dec, distance, m, r, use_completeness=False, use_efficiency=True)
#      22             stars = sim.stars
#      23             angseps = ugali.utils.projector.angsep(ra, dec, stars['RA'], stars['DEC'])
#
# /Users/mcnanna/Research/y6/v2_y6_dwarf_search/simulations/simSatellite.py in __init__(self, inputs, lon_centroid, lat_centroid, distance, abs_mag, r_physical, ellipticity, use_completeness, use_efficiency)
#      50         iso = simple.isochrone.get_isochrone(iso_type, survey='des', age=12., z=0.0001, distance_modulus=distance_modulus)
#      51         s.set_isochrone(iso)
# ---> 52         mag_g, mag_r, mag_i = s.isochrone.simulate(abs_mag)
#      53
#      54         lon, lat = s.kernel.sample_lonlat(len(mag_r))
#
# /Users/mcnanna/Research/simple/simple/isochrone.py in simulate(self, abs_mag, distance_modulus, **kwargs)
#     219             f_i = scipy.interpolate.interp1d(self.mass_init, self.data['i']+self.distance_modulus)
#     220             mass_init_sample = self.imf.sample(n, np.min(self.mass_init), np.max(self.mass_init), **kwargs)
# --> 221             mag_g_sample, mag_r_sample, mag_i_sample = f_g(mass_init_sample), f_r(mass_init_sample), f_i(mass_init_sample)
#     222             return mag_g_sample, mag_r_sample, mag_i_sample
#     223
#
# /Users/mcnanna/anaconda2/envs/ugali-env/lib/python2.7/site-packages/scipy/interpolate/polyint.pyc in __call__(self, x)
#      77         """
#      78         x, x_shape = self._prepare_x(x)
# ---> 79         y = self._evaluate(x)
#      80         return self._finish_y(y, x_shape)
#      81
#
# /Users/mcnanna/anaconda2/envs/ugali-env/lib/python2.7/site-packages/scipy/interpolate/interpolate.pyc in _evaluate(self, x_new)
#     660         #    The behavior is set by the bounds_error variable.
#     661         x_new = asarray(x_new)
# --> 662         y_new = self._call(self, x_new)
#     663         if not self._extrapolate:
#     664             below_bounds, above_bounds = self._check_bounds(x_new)
#
# /Users/mcnanna/anaconda2/envs/ugali-env/lib/python2.7/site-packages/scipy/interpolate/interpolate.pyc in _call_linear_np(self, x_new)
#     584     def _call_linear_np(self, x_new):
#     585         # Note that out-of-bounds values are taken care of in self._evaluate
# --> 586         return np.interp(x_new, self.x, self.y)
#     587
#     588     def _call_linear(self, x_new):
#
# /Users/mcnanna/anaconda2/envs/ugali-env/lib/python2.7/site-packages/numpy/lib/function_base.pyc in interp(x, xp, fp, left, right, period)
#    1306         fp = np.concatenate((fp[-1:], fp, fp[0:1]))
#    1307
# -> 1308     return interp_func(x, xp, fp, left, right)
#    1309
#    1310
#
# KeyboardInterrupt:

# %%
np.save('densities_cutoff.npy', densities)

# %%
blended = densities > 1
for i in range(n_r):
    for j in range(n_m):
        if blended[i,j,0]:
            print(round(np.log10(r_physicals[i]), 1), abs_mags[j], np.count_nonzero(blended[i,j]))
# Out:
# (1.4, -4.0, 1)
# (1.4, -4.5, 2)
# (1.4, -5.0, 3)
# (1.4, -5.5, 3)
# (1.4, -6.0, 3)
# (1.4, -6.5, 3)
# (1.4, -7.0, 3)
# (1.4, -7.5, 3)
# (1.4, -8.0, 3)
# (1.4, -8.5, 3)
# (1.4, -9.0, 3)
# (1.4, -9.5, 3)
# (1.4, -10.0, 3)
# (1.4, -10.5, 3)
# (1.4, -11.0, 3)
# (1.4, -11.5, 3)
# (1.4, -12.0, 3)
# (1.4, -12.5, 3)
# (1.4, -13.0, 3)
# (1.4, -13.5, 3)
# (1.4, -14.0, 3)
# (1.6, -5.0, 1)
# (1.6, -5.5, 1)
# (1.6, -6.0, 2)
# (1.6, -6.5, 3)
# (1.6, -7.0, 3)
# (1.6, -7.5, 3)
# (1.6, -8.0, 3)
# (1.6, -8.5, 3)
# (1.6, -9.0, 3)
# (1.6, -9.5, 3)
# (1.6, -10.0, 3)
# (1.6, -10.5, 3)
# (1.6, -11.0, 3)
# (1.6, -11.5, 3)
# (1.6, -12.0, 3)
# (1.6, -12.5, 3)
# (1.6, -13.0, 3)
# (1.6, -13.5, 3)
# (1.6, -14.0, 3)
# (1.8, -6.0, 1)
# (1.8, -6.5, 2)
# (1.8, -7.0, 3)
# (1.8, -7.5, 3)
# (1.8, -8.0, 3)
# (1.8, -8.5, 3)
# (1.8, -9.0, 3)
# (1.8, -9.5, 3)
# (1.8, -10.0, 3)
# (1.8, -10.5, 3)
# (1.8, -11.0, 3)
# (1.8, -11.5, 3)
# (1.8, -12.0, 3)
# (1.8, -12.5, 3)
# (1.8, -13.0, 3)
# (1.8, -13.5, 3)
# (1.8, -14.0, 3)
# (2.0, -7.0, 1)
# (2.0, -7.5, 1)
# (2.0, -8.0, 2)
# (2.0, -8.5, 3)
# (2.0, -9.0, 3)
# (2.0, -9.5, 3)
# (2.0, -10.0, 3)
# (2.0, -10.5, 3)
# (2.0, -11.0, 3)
# (2.0, -11.5, 3)
# (2.0, -12.0, 3)
# (2.0, -12.5, 3)
# (2.0, -13.0, 3)
# (2.0, -13.5, 3)
# (2.0, -14.0, 3)
# (2.2, -8.5, 1)
# (2.2, -9.0, 2)
# (2.2, -9.5, 3)
# (2.2, -10.0, 3)
# (2.2, -10.5, 3)
# (2.2, -11.0, 3)
# (2.2, -11.5, 3)
# (2.2, -12.0, 3)
# (2.2, -12.5, 3)
# (2.2, -13.0, 3)
# (2.2, -13.5, 3)
# (2.2, -14.0, 3)
# (2.4, -9.5, 1)
# (2.4, -10.0, 2)
# (2.4, -10.5, 3)
# (2.4, -11.0, 3)
# (2.4, -11.5, 3)
# (2.4, -12.0, 3)
# (2.4, -12.5, 3)
# (2.4, -13.0, 3)
# (2.4, -13.5, 3)
# (2.4, -14.0, 3)
# (2.6, -10.5, 1)
# (2.6, -11.0, 2)
# (2.6, -11.5, 3)
# (2.6, -12.0, 3)
# (2.6, -12.5, 3)
# (2.6, -13.0, 3)
# (2.6, -13.5, 3)
# (2.6, -14.0, 3)
# (2.8, -11.5, 1)
# (2.8, -12.0, 2)
# (2.8, -12.5, 3)
# (2.8, -13.0, 3)
# (2.8, -13.5, 3)
# (2.8, -14.0, 3)
# (3.0, -12.5, 1)
# (3.0, -13.0, 1)
# (3.0, -13.5, 3)
# (3.0, -14.0, 3)

# %%
log_r_physical_pcs[9]
abs_mags[-2]
# Out:
# -13.5

# %%
densities[9][-1] = 99.9, 99.9, 99.9
